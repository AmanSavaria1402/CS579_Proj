# %% [markdown]
# This file is for exploration and experimentation for checking if the various aspects of the project would work

# %%
import pandas as pd
import numpy as np
import os
import networkx as nx
import torch
from tqdm import tqdm
import geopandas as gpd
import shapely as geom
from shapely.geometry import Point, LineString
import plotly.graph_objects as go

# %% [markdown]
# # Trying to create the L stations graph
#
# Source: https://chatgpt.com/c/691fae02-c184-8329-a7e9-9b9ab07aba60

# %%
# loading the shapefile
stations = gpd.read_file("data/l_stations/CTA_RailStations.shp")
rails = gpd.read_file("data/l_lines/geo_export_717b00c4-60f6-4164-86a6-4a25f7d068de.shp")

# %%
print(stations.crs)
print(rails.crs)
# Out:
# EPSG:3435
# EPSG:4326

# %% [markdown]
# Changing to EPSG:26916

# %%
stations = stations.to_crs(epsg=26916)
rails = rails.to_crs(epsg=26916)

# %%
stations.columns, rails.columns
# Out:
# (Index(['STATION_ID', 'LONGNAME', 'LINES', 'ADDRESS', 'ADA', 'PKNRD', 'POINT_X',
#         'POINT_Y', 'geometry'],
#        dtype='object'),
#  Index(['lines', 'descriptio', 'type', 'legend', 'shape_len', 'geometry'], dtype='object'))

# %%
stations.head(1)
# Out:
#    STATION_ID    LONGNAME      LINES                    ADDRESS  ADA  PKNRD  \
# 0         230  Cumberland  Blue Line  5800 N. Cumberland Avenue    1      1
#
#         POINT_X       POINT_Y                        geometry
# 0  1.118914e+06  1.937256e+06  POINT (430579.352 4648372.031)

# %% [markdown]
# Create a graph

# %%
G = nx.Graph()

# Add all stations as nodes
for idx, row in stations.iterrows():
    G.add_node(row['LONGNAME'], pos=(row.geometry.x, row.geometry.y))

# %% [markdown]
# Connect stations using line geometries

# %%
def nearest_station(point, stations_gdf):
    # returns the nearest station name to a point
    distances = stations_gdf.geometry.distance(point)
    return stations_gdf.iloc[distances.idxmin()]['LONGNAME']

for idx, row in rails.iterrows():
    line_geom = row.geometry
    if line_geom.geom_type == 'MultiLineString':
        line_geom = max(line_geom, key=lambda l: l.length)
    
    # Get start and end points of the line
    start_point = Point(line_geom.coords[0])
    end_point = Point(line_geom.coords[-1])
    
    s1 = nearest_station(start_point, stations)
    s2 = nearest_station(end_point, stations)
    
    if s1 != s2:
        G.add_edge(s1, s2)

# %% [markdown]
# Visualizing the graph

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
pos = nx.get_node_attributes(G, 'pos')
nx.draw(G, pos, with_labels=True, node_size=50)
plt.show()

# %%
node_x = []
node_y = []
for node in G.nodes():
    x, y = G.nodes[node]['pos']
    node_x.append(x)
    node_y.append(y)

# %%
cmap = {
    'Blue Line':'#0AA7E0',
    'Green Line (Lake)': "#1EDB37",
    'Green (Lake), Pink': "#0B2B03",
    "Blue Line (O'Hare)": "#044E69",
    'Brown, Purple (Express)': "#331406",
    'Brown Line': "#532A04",
    'Brown, Orange, Pink, Purple (Express)': "#2A0481",
    'Brown, Orange, Pink,  Purple (Express), Green': "#2A0481",
    'Red Line': "#DA0A0A",
    'Green Line': "#1CE00A",
    'Green Line (Englewood)': "#1CE00A",
    'Orange & Green Lines': "#E0830A",
    'Red, Brown, Purple (Express)': "#550303",
    'Purple Line, Evanston Express': "#2A0481",
    'Red, Yellow, Purple, Evanston Express': "#321D64",
    'Yellow Line': "#BDBA0B",
    'Blue Line (Congress)': "#5FBAE4",
    'Orange Line': "#C56D09",
    'Pink': "#7D0481",
     'Purple, Red Line': "#410E63",
    'Brown, Orange, Pink, Purple (Express), Green, Blue': "#523509"
}

# %%
# creating a line color
line_color = stations['LINES'].map(lambda l: cmap[l])

# %%
node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        # colorscale options
        #'Greys' | 'YlGnBu' | 'Greens' | 'YlOrRd' | 'Bluered' | 'RdBu' |
        #'Reds' | 'Blues' | 'Picnic' | 'Rainbow' | 'Portland' | 'Jet' |
        #'Hot' | 'Blackbody' | 'Earth' | 'Electric' | 'Viridis' |
        colorscale='YlGnBu',
        reversescale=True,
        color=line_color,
        size=10,
        colorbar=dict(
            thickness=15,
            title=dict(
              text='Node Connections',
              side='right'
            ),
            xanchor='left',
        ),
        line_width=2),
      text=stations['LONGNAME'])

# %%
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = G.nodes[edge[0]]['pos']
    x1, y1 = G.nodes[edge[1]]['pos']
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

# %%
fig = go.Figure(data=[edge_trace, node_trace],
             layout=go.Layout(
                title=dict(
                    text="CTA L-Graph",
                    font=dict(
                        size=16
                    )
                ),
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20,l=5,r=5,t=40),
                xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                )
fig.update_layout(
    autosize=False,
    width=1000,
    height=1000,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
    paper_bgcolor="LightSteelBlue",
)
fig.show()

# %%
stations['LINES'].unique()
# Out:
# array(['Blue Line', 'Green Line (Lake)', 'Green (Lake), Pink',
#        "Blue Line (O'Hare)", 'Brown, Purple (Express)', 'Brown Line',
#        'Brown, Orange, Pink, Purple (Express)',
#        'Brown, Orange, Pink,  Purple (Express), Green', 'Red Line',
#        'Green Line', 'Green Line (Englewood)', 'Orange & Green Lines',
#        'Red, Brown, Purple (Express)', 'Purple Line, Evanston Express',
#        'Red, Yellow, Purple, Evanston Express', 'Yellow Line',
#        'Blue Line (Congress)', 'Orange Line', 'Pink', 'Purple, Red Line',
#        'Brown, Orange, Pink, Purple (Express), Green, Blue'], dtype=object)
